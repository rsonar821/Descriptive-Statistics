# %% [markdown]
# <a href="https://colab.research.google.com/github/rsonar821/Descriptive-Statistics/blob/main/Descriptive_Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Descriptive Statistics**

# %% [markdown]
# This notebook gives you the complete information regarding descriptive statistics

# %%
# Importing basic libraries
import numpy as np
import pandas as pd
import math
import statistics as st
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Mounting google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing data and declaring a dataframe
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Innomatics/data.csv')

# %%
# First 5 rows of dataframe
df.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %%
# Columns of the dataframe
df.columns
# Out:
# Index(['Mthly_HH_Income', 'Mthly_HH_Expense', 'No_of_Fly_Members',
#        'Emi_or_Rent_Amt', 'Annual_HH_Income', 'Highest_Qualified_Member',
#        'No_of_Earning_Members'],
#       dtype='object')

# %%
# Shape of the dataset
print(f'The dataset has {df.shape[0]} rows and {df.shape[1]} columns')
# Out:
# The dataset has 50 rows and 7 columns

# %%
# Changing column names for simplicity
df.rename(columns={'Mthly_HH_Income':'monthly_income', 'Mthly_HH_Expense':'monthly_expense',
                   'No_of_Fly_Members':'family_members', 'Emi_or_Rent_Amt':'rent_amount',
                   'Annual_HH_Income':'annual_income', 'Highest_Qualified_Member':'highest_qualification',
                   'No_of_Earning_Members':'earning_members'}, inplace=True)

# %%
# First 5 rows of the dataframe
df.head()
# Out:
#    monthly_income  monthly_expense  family_members  rent_amount  \
# 0            5000             8000               3         2000
# 1            6000             7000               2         3000
# 2           10000             4500               2            0
# 3           10000             2000               1            0
# 4           12500            12000               2         3000
#
#    annual_income highest_qualification  earning_members
# 0          64200        Under-Graduate                1
# 1          79920            Illiterate                1
# 2         112800        Under-Graduate                1
# 3          97200            Illiterate                1
# 4         147000              Graduate                1

# %% [markdown]
# ## **1. Mean**

# %% [markdown]
# In statistics, the mean is one of the measures of central tendency, apart from the mode and median. Mean is nothing but the average of the given set of values. It denotes the equal distribution of values for a given data set. To calculate the mean, we need to add the total values given in a dataset and divide the sum by the total number of values.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Calculating the mean from the dataset
print(f"The mean of the monthly income is {df['monthly_income'].mean()} \n")
print(f"The mean of the monthly expense is {df['monthly_expense'].mean()} \n")
print(f"The mean of the monthly rent/EMI amount is {df['rent_amount'].mean()} \n")
print(f"The mean of the annual income is {df['annual_income'].mean()}")
# Out:
# The mean of the monthly income is 41558.0
#
# The mean of the monthly expense is 18818.0
#
# The mean of the monthly rent/EMI amount is 3060.0
#
# The mean of the annual income is 490019.04

# %% [markdown]
# ## **2. Median**

# %% [markdown]
# The median is the middle number in a sorted, ascending or descending list of numbers and can be more descriptive of that data set than the average. It is the point above and below which half (50%) the observed data falls, and so represents the midpoint of the data. Median is termed as Q2 in the terms of quartile which indicates as the middle value and separates data in exactly 2 equal parts.
#
#
# *   If there is an odd amount of numbers, the median value is the number that is in the middle, with the same amount of numbers below and above.
#
# *   If there is an even amount of numbers in the list, the middle pair must be determined, added together, and divided by two to find the median value.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Calculating the median from the dataset
print(f"The median of the monthly income is {df['monthly_income'].median()} \n")
print(f"The median of the monthly expense is {df['monthly_expense'].median()} \n")
print(f"The median of the monthly rent/EMI amount is {df['rent_amount'].median()} \n")
print(f"The median of the annual income is {df['annual_income'].median()}")
# Out:
# The median of the monthly income is 35000.0
#
# The median of the monthly expense is 15500.0
#
# The median of the monthly rent/EMI amount is 0.0
#
# The median of the annual income is 447420.0

# %% [markdown]
# ## **3. Mode**

# %% [markdown]
# The mode is the value that appears most often in a set of data values. If X is a discrete random variable, the mode is the value x at which the probability mass function takes its maximum value. In other words, it is the value that is most likely to be sampled.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Calculating the mode from the dataset
print(f"The mode of the monthly income is {df['monthly_income'].mode()[0]} \n")
print(f"The mode of the monthly expense is {df['monthly_expense'].mode()[0]} \n")
print(f"The mode of the monthly rent/EMI amount is {df['rent_amount'].mode()[0]} \n")
print(f"The mode of the annual income is {df['annual_income'].mode()[0]}")
# Out:
# The mode of the monthly income is 45000
#
# The mode of the monthly expense is 25000
#
# The mode of the monthly rent/EMI amount is 0
#
# The mode of the annual income is 590400

# %% [markdown]
# ## **4. Variance**

# %% [markdown]
# The term variance refers to a statistical measurement of the spread between numbers in a data set. More specifically, variance measures how far each number in the set is from the mean (average), and thus from every other number in the set. Variance is often depicted by this symbol: σ2. It is used by both analysts and traders to determine volatility and market security.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Calculating the variance from the dataset
print(f"The variance of the monthly income is {round(st.variance(df['monthly_income']), 2)} \n")
print(f"The variance of the monthly expense is {round(st.variance(df['monthly_expense']), 2)} \n")
print(f"The variance of the monthly rent/EMI amount is {round(st.variance(df['rent_amount']), 2)} \n")
print(f"The variance of the annual income is {round(st.variance(df['annual_income']), 2)}")
# Out:
# The variance of the monthly income is 681100853.06
#
# The variance of the monthly expense is 146173342.86
#
# The variance of the monthly rent/EMI amount is 38955510.2
#
# The variance of the annual income is 102486925397.92

# %% [markdown]
# ## **5. Standard Deviation**

# %% [markdown]
# Standard deviation is a statistic that measures the dispersion of a dataset relative to its mean and is calculated as the square root of the variance. The standard deviation is calculated as the square root of variance by determining each data point's deviation relative to the mean.
#
# If the data points are further from the mean, there is a higher deviation within the data set; thus, the more spread out the data, the higher the standard deviation.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Calculating the standard deviation from the dataset
print(f"The standard deviation of the monthly income is {round(st.stdev(df['monthly_income']), 2)} \n")
print(f"The standard deviation of the monthly expense is {round(st.stdev(df['monthly_expense']), 2)} \n")
print(f"The standard deviation of the monthly rent/EMI amount is {round(st.stdev(df['rent_amount']), 2)} \n")
print(f"The standard deviation of the annual income is {round(st.stdev(df['annual_income']), 2)}")
# Out:
# The standard deviation of the monthly income is 26097.91
#
# The standard deviation of the monthly expense is 12090.22
#
# The standard deviation of the monthly rent/EMI amount is 6241.43
#
# The standard deviation of the annual income is 320135.79
